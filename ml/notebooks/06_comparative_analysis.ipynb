# %% [markdown]
# # 06 — Comparative Analysis: DeiT-Tiny vs ResNet-50
#
# **Owner:** Rishav Dhakal + Yashraj Shrestha
#
# Compare both models on the **same held-out test set**.
#
# **Hypothesis:** DeiT will outperform CNN by 2-3% (Kumar et al., 2024)
#
# This validates our architectural choice of DeiT over traditional CNN.

# %%
# TODO: Load both models and evaluate on same test_loader

# %% [markdown]
# ## 1. Evaluate Both Models

# %%
# TODO (Rishav):
# deit_metrics = evaluate_model(deit_student, test_loader)
# resnet_metrics = evaluate_model(resnet_teacher, test_loader)

# %% [markdown]
# ## 2. Metrics Comparison Table

# %%
# TODO (Rishav): comparison = compare_models(deit_metrics, resnet_metrics)
# Expected table:
# | Metric   | DeiT-Tiny | ResNet-50 | Δ     |
# |----------|-----------|-----------|-------|
# | Accuracy | xx.x%     | xx.x%     | +x.x% |

# %% [markdown]
# ## 3. Model Comparison Chart

# %%
# TODO (Rishav): plot_model_comparison(deit_metrics, resnet_metrics, save_path='figures/model_comparison.png')

# %% [markdown]
# ## 4. Conclusions
#
# Fill in after running evaluation:
# - DeiT accuracy vs ResNet-50 accuracy
# - Latency comparison
# - Recommendation

# %%
print('Fill in conclusions after running evaluation')

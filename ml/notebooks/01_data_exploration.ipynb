# %% [markdown]
# # 01 — Data Exploration
#
# **Owner:** Rishi Kumar Kushwaha (Data Engineering Lead)
#
# Explore PlantVillage dataset: class distribution, image statistics, samples.
#
# **Prerequisite:** PlantVillage dataset in `data/raw/PlantVillage/`

# %%
import os, sys
from pathlib import Path
sys.path.append('../..')
# TODO (Rishi): Import numpy, matplotlib, PIL, Counter

# %% [markdown]
# ## 1. Dataset Overview
#
# Count images per class and verify 15 classes are present.

# %%
# TODO (Rishi): Count images per folder
# data_dir = Path('../../data/raw/PlantVillage')
# class_counts = {folder.name: len(list(folder.glob('*.jpg'))) for folder in data_dir.iterdir() if folder.is_dir()}
# print(f'Total classes: {len(class_counts)}, Total images: {sum(class_counts.values())}')

# %% [markdown]
# ## 2. Class Distribution Plot

# %%
# TODO (Rishi): plt.bar(class_counts.keys(), class_counts.values()) — identify imbalanced classes

# %% [markdown]
# ## 3. Sample Images — 2 samples per class

# %%
# TODO (Rishi): Display image grid (5 rows × 3 cols sample)

# %% [markdown]
# ## 4. Image Statistics
#
# Verify ImageNet normalization parameters work for our dataset.

# %%
# TODO (Rishi): Compute pixel mean/std across training set
# Expected: mean ≈ [0.485, 0.456, 0.406], std ≈ [0.229, 0.224, 0.225]

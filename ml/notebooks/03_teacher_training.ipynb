# %% [markdown]
# # 03 — ResNet-50 Teacher Training
#
# **Owner:** Yashraj Shrestha (AI Lead)
#
# **Phase 1:** Train ResNet-50 on PlantVillage (15 classes).
#
# **Platform:** Kaggle T4 GPU | **Duration:** ~3-4 hours | **Target:** ≥85% accuracy
#
# **Enable GPU:** Kaggle Settings → Accelerator → GPU T4 x2

# %%
import torch
print(f'PyTorch: {torch.__version__}, CUDA: {torch.cuda.is_available()}')
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## 1. Create ResNet-50 Teacher

# %%
# TODO (Yashraj): from ml.src.models.teacher import create_teacher_model
# model = create_teacher_model(num_classes=15, pretrained=True).to(device)

# %% [markdown]
# ## 2. Configure Optimizer and Scheduler

# %%
# TODO (Yashraj):
# optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5)

# %% [markdown]
# ## 3. Train (30 epochs, early stopping patience=7)

# %%
# TODO (Yashraj): trainer = Trainer(...)
# history = trainer.train(train_loader, val_loader, loss_fn, num_epochs=30, patience=7)

# %% [markdown]
# ## 4. Plot Training Curves

# %%
# TODO (Yashraj): plot_training_curves(history)

# %% [markdown]
# # 04 — DeiT-Tiny Knowledge Distillation
#
# **Owner:** Yashraj Shrestha (AI Lead)
#
# **Phase 2:** Train DeiT-Tiny student via knowledge distillation.
#
# **PREREQUISITE:** Run notebook 03 first.
#
# **Key settings:** alpha=0.7, temperature=4.0 (Hinton et al., 2015; Touvron et al., 2021)
#
# **Platform:** Kaggle T4 GPU | **Duration:** ~4-5 hours | **Target:** ≥85% accuracy

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device: {device}')

# %% [markdown]
# ## 1. Load Trained Teacher

# %%
# TODO (Yashraj):
# from ml.src.models.teacher import create_teacher_model
# teacher = create_teacher_model(num_classes=15, pretrained=False)
# teacher.load_state_dict(torch.load('../../models/teacher/resnet50_plant_teacher.pth'))
# teacher.eval()
# print('Teacher loaded.')

# %% [markdown]
# ## 2. Create DeiT-Tiny Student

# %%
# TODO (Yashraj):
# from ml.src.models.student import create_student_model
# student = create_student_model(num_classes=15).to(device)
# summary = get_model_summary(student)
# print(f"Parameters: {summary['total_params']:,} (~5.7M expected)")

# %% [markdown]
# ## 3. Train with Knowledge Distillation
#
# alpha=0.7: 70% soft labels (teacher) + 30% hard labels (ground truth)
# temperature=4.0: softens probability distributions for richer transfer

# %%
# TODO (Yashraj):
# from ml.src.models.distillation import DistillationLoss
# loss_fn = DistillationLoss(alpha=0.7, temperature=4.0)
# history = trainer.train(train_loader, val_loader, loss_fn, num_epochs=50, patience=10)

# %% [markdown]
# ## 4. Save Student Model

# %%
# Trainer auto-saves best checkpoint
# Verify:
import os
print('Student saved:', os.path.exists('../../models/student/deit_tiny_plant_diagnosis.pth'))

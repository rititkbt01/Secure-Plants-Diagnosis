# %% [markdown]
# # 05 — Model Evaluation
#
# **Owner:** Rishav Dhakal (Model Optimization Lead)
#
# Evaluate DeiT-Tiny on **held-out test set** (never seen during training).
#
# **Targets:** Accuracy≥85%, F1≥0.88, Inference<3s

# %%
import torch, sys
sys.path.append('../..')
device = 'cpu'
# from ml.src.models.student import create_student_model
# from ml.src.evaluation.metrics import evaluate_model, compute_inference_time

# %% [markdown]
# ## 1. Load DeiT-Tiny Student

# %%
# TODO (Rishav): Load student model

# %% [markdown]
# ## 2. Evaluate on Test Set

# %%
# TODO (Rishav): metrics = evaluate_model(model, test_loader)
# print(f"Accuracy: {metrics['accuracy']:.4f} (target: >=0.85)")
# print(f"F1-Score: {metrics['macro_f1']:.4f} (target: >=0.88)")
# print(f"Precision: {metrics['macro_precision']:.4f} (target: >=0.85)")
# print(f"Recall: {metrics['macro_recall']:.4f} (target: >=0.85)")

# %% [markdown]
# ## 3. Confusion Matrix

# %%
# TODO (Rishav): plot_confusion_matrix(metrics['confusion_matrix'], class_names)

# %% [markdown]
# ## 4. Inference Time

# %%
# TODO (Rishav): timing = compute_inference_time(model, num_samples=100)
# print(f"Mean: {timing['mean_ms']:.0f}ms (target: <3000ms)")

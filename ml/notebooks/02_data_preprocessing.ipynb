# %% [markdown]
# # 02 — Data Preprocessing
#
# **Owner:** Rishi Kumar Kushwaha
#
# Verify dataset integrity, create train/val/test splits (70/15/15), test augmentation pipeline.

# %%
import sys
sys.path.append('../..')
# from ml.src.data.preprocessing import verify_dataset_integrity, create_data_splits

# %% [markdown]
# ## 1. Verify Dataset Integrity (detect corrupt images)

# %%
# TODO (Rishi): corrupt = verify_dataset_integrity('../../data/raw/PlantVillage')
# print(f'Corrupt files: {len(corrupt)}')

# %% [markdown]
# ## 2. Create Stratified Train/Val/Test Splits

# %%
# TODO (Rishi): splits = create_data_splits('../../data/raw/PlantVillage')
# print(f"Train:{len(splits['train'])} Val:{len(splits['val'])} Test:{len(splits['test'])}")

# %% [markdown]
# ## 3. Verify Augmentation Visually
#
# Show original vs augmented images side-by-side.

# %%
# TODO (Rishi): Display image before/after each augmentation step

# %% [markdown]
# ## 4. DataLoader Batch Test

# %%
# TODO (Rishi): Create DataLoader, load one batch
# Expected batch shape: torch.Size([32, 3, 224, 224])
